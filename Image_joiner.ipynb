# %%
import torch
import numpy as np

# %%
image = np.load('00098-AAAA-STI.npy', allow_pickle=True)

# %%
image[0][0].shape
# Out:
# (4, 64, 256, 256)

# %%
import matplotlib.pyplot as plt
plt.imshow(image[0][0][3][30])

# %%
image_tensor = torch.from_numpy(image[0][0])

# %%
im1_t = image_tensor[0]
im2_t = image_tensor[1]
im3_t = image_tensor[2]
im4_t = image_tensor[3]

# %%
im_t = torch.vstack((im1_t, im2_t, im3_t, im4_t))

# %%
im_t.shape
# Out:
# torch.Size([256, 256, 256])

# %%
plt.imshow(im_t[100])
